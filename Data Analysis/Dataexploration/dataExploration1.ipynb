# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.8 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.8 MB 7.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.8 MB 8.3 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 9.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv(r"C:\FBS\Data Analysis\Dataexploration\cars93.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv(r"C:\FBS\Data Analysis\Dataexploration\cars93.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df=pd.read_csv(r"C:\FBS\Data Analysis\Dataexploration\cars93.csv")

# %%
df.head()
# Out:
#   Manufacturer    Model     Type    Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small  3259500        25         Driver only
# 1        Acura   Legend  Midsize  6949500        18  Driver & Passenger
# 2         Audi       90  Compact  5965500        20         Driver only
# 3         Audi      100  Midsize  7728500        19  Driver & Passenger
# 4          BMW     535i  Midsize  6150000        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
print("rows:",df.shape[0])
print("columns",df.shape[1])
# Out:
# rows: 93
# columns 10

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Price', 'MPG.city', 'AirBags',
#        'Horsepower', 'Passengers', 'Rear.seat.room', 'Luggage.room'],
#       dtype='str')

# %%
df.describe()
# Out:
#               Price   MPG.city  Horsepower  Passengers  Rear.seat.room  \
# count  9.300000e+01  93.000000   93.000000   93.000000       91.000000
# mean   3.999484e+06  22.365591  143.827957    5.086022       27.829670
# std    1.980183e+06   5.619812   52.374410    1.038979        2.989072
# min    1.517000e+06  15.000000   55.000000    2.000000       19.000000
# 25%    2.501000e+06  18.000000  103.000000    4.000000       26.000000
# 50%    3.628500e+06  21.000000  140.000000    5.000000       27.500000
# 75%    4.776500e+06  25.000000  170.000000    6.000000       30.000000
# max    1.268950e+07  46.000000  300.000000    8.000000       36.000000
#
#        Luggage.room
# count     82.000000
# mean      13.890244
# std        2.997967
# min        6.000000
# 25%       12.000000
# 50%       14.000000
# 75%       15.000000
# max       22.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Manufacturer    93 non-null     str
#  1   Model           93 non-null     str
#  2   Type            93 non-null     str
#  3   Price           93 non-null     int64
#  4   MPG.city        93 non-null     int64
#  5   AirBags         79 non-null     str
#  6   Horsepower      93 non-null     int64
#  7   Passengers      93 non-null     int64
#  8   Rear.seat.room  91 non-null     float64
#  9   Luggage.room    82 non-null     float64
# dtypes: float64(2), int64(4), str(4)
# memory usage: 7.4 KB

# %%
df.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
#handling missing value

# %%
df['Rear.seat.room'].mean()
# Out:
# np.float64(27.82967032967033)

# %%
df['Rear.seat.room'].median()
# Out:
# np.float64(27.5)

# %%
x=df['Rear.seat.room'].median()

# %%
df['Rear.seat.room']=df['Rear.seat.room'].fillna(value=x)

# %%
df.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     0
# Luggage.room      11
# dtype: int64

# %%
df['Luggage.room'].mean()
# Out:
# np.float64(13.890243902439025)

# %%
df['Luggage.room'].median()
# Out:
# np.float64(14.0)

# %%
t=df['Luggage.room'].median()

# %%
df['Luggage.room']=df['Luggage.room'].fillna(value=t)

# %%
df.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     0
# Luggage.room       0
# dtype: int64

# %%
# using mode to handle string type missing data

# %%
df['AirBags'].mode()[0]
# Out:
# 'Driver only'

# %%
x=df['AirBags'].mode()[0]

# %%
df['AirBags']=df['AirBags'].fillna(value=x)

# %%
df.isna().sum()
# Out:
# Manufacturer      0
# Model             0
# Type              0
# Price             0
# MPG.city          0
# AirBags           0
# Horsepower        0
# Passengers        0
# Rear.seat.room    0
# Luggage.room      0
# dtype: int64

# %%
# normalization 0 to 1

# %%
df.head()
# Out:
#   Manufacturer    Model     Type    Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small  3259500        25         Driver only
# 1        Acura   Legend  Midsize  6949500        18  Driver & Passenger
# 2         Audi       90  Compact  5965500        20         Driver only
# 3         Audi      100  Midsize  7728500        19  Driver & Passenger
# 4          BMW     535i  Midsize  6150000        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 3.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.8/8.2 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.2 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.2 MB 3.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.2 MB 3.5 MB/s eta 0:00:02
#    --------------------- ------------------ 4.5/8.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 4.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max=MinMaxScaler()

# %%
price_normalised=min_max.fit_transform(df[['Price']])

# %%
price_normalised.min()
# Out:
# np.float64(0.0)

# %%
price_normalised.max()
# Out:
# np.float64(1.0)

# %%
# adding new normalized column into our existing dataframe

# %%
df['price_normalised']=price_normalised

# %%
# applying standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
std_scaler=StandardScaler()

# %%
Horsepower_std=std_scaler.fit_transform(df[['Horsepower']])

# %%
df['Horsepower_std']=Horsepower_std

# %%
df['Horsepower_std'].min()
# Out:
# np.float64(-1.705210877485415)

# %%
df['Horsepower_std'].max()
# Out:
# np.float64(2.998000579179055)

# %%
# data encoding

# %%
# one hot encoding

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Manufacturer      93 non-null     str
#  1   Model             93 non-null     str
#  2   Type              93 non-null     str
#  3   Price             93 non-null     int64
#  4   MPG.city          93 non-null     int64
#  5   AirBags           93 non-null     str
#  6   Horsepower        93 non-null     int64
#  7   Passengers        93 non-null     int64
#  8   Rear.seat.room    93 non-null     float64
#  9   Luggage.room      93 non-null     float64
#  10  price_normalised  93 non-null     float64
#  11  Horsepower_std    93 non-null     float64
# dtypes: float64(4), int64(4), str(4)
# memory usage: 8.8 KB

# %%
df_encoded=pd.get_dummies(df)

# %%
df_encoded.shape[1]
# Out:
# 141

# %%
df_encoded.shape
# Out:
# (93, 141)

# %%
len(df['Model'].unique())
# Out:
# 93

# %%
len(df['Manufacturer'].unique())
# Out:
# 32

# %%
len(df['Type'].unique())
# Out:
# 6

# %%
len(df['AirBags'].unique())
# Out:
# 2

# %%
df.shape
# Out:
# (93, 12)

# %%
12+2+32+6+93
# Out:
# 145

# %%
145-4 # colums are replace
# Out:
# 141

# %%
df_encoded.shape
# Out:
# (93, 141)

# %%
#label encoding

# %%
df.AirBags.unique()
# Out:
# <StringArray>
# ['Driver only', 'Driver & Passenger']
# Length: 2, dtype: str

# %%
df.Type.unique()
# Out:
# <StringArray>
# ['Small', 'Midsize', 'Compact', 'Large', 'Sporty', 'Van']
# Length: 6, dtype: str

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
df_encoded=label_encoder.fit_transform(df["Type"])

# %%
df_encoded
# Out:
# array([3, 2, 0, 2, 2, 2, 1, 1, 2, 1, 2, 0, 0, 4, 2, 5, 5, 1, 4, 1, 0, 1,
#        3, 3, 0, 5, 2, 4, 3, 1, 3, 3, 0, 4, 4, 5, 2, 1, 3, 4, 4, 3, 0, 3,
#        3, 4, 2, 2, 2, 2, 2, 1, 3, 3, 0, 5, 4, 0, 2, 4, 2, 3, 2, 3, 0, 5,
#        2, 0, 2, 5, 1, 4, 3, 0, 4, 2, 1, 0, 3, 3, 3, 0, 3, 3, 4, 2, 5, 3,
#        5, 0, 4, 0, 2])

# %%
df['Type_encoded']=df_encoded
